# %%
import pandas as pd
import os
from blastScripts import make_queries as mq
import shutil

# %% [markdown]
# ### Directions:
# 1. Need to have directory with proteomes with '.faa' extension.
#     - can also move typical ncbi_datasets file structure and use the function below to pull out the proteomes to their own directory
# 2. make a text file with all accessions in it
#     -this is only necessary if you don't want to make blastp databases from all of the proteomes
# 3.

# %% [markdown]
# ### If starting with ncbi datasets directory structure, move proteomes to their own directory

# %%
def move_ncbi_datasets_proteomes(data_folder):
    proteomes_dir = './Proteomes'
    if not os.path.exists(proteomes_dir):
        os.makedirs(proteomes_dir)
    assembly_dirs = [f for f in os.listdir(p_dir) if f.startswith('GC')]
    for assemb_dir in assembly_dirs:
        fp = os.path.join(p_dir,assemb_dir)
        files = os.listdir(fp)
        for file in files:
            if file.endswith('.faa'):
                proteome_fp = os.path.join(fp, file)
                name = assemb_dir + '.faa'
                new_fp = os.path.join(proteomes_dir,name)
                shutil.move(proteome_fp, new_fp )

data_folder =  './ncbi_dataset/ncbi_dataset/data'
#move_ncbi_datasets_proteomes(data_folder)

# %% [markdown]
# ### accessions of proteomes used to build blastp databases

# %%
deduped_accessions_w_palmer_strains = []
with open('./deduped_accessions_w_palmer_strains.txt', 'r') as f:
    for line in f:
        deduped_accessions_w_palmer_strains.append(line.strip())

# %% [markdown]
# ### Functions

# %%
def make_blastp_databases(proteome_dir, out_dir, proteomes_to_include=None):
    """Make a blastp database for each proteome within a given directory"""
    
    if not proteomes_to_include:
        proteomes_to_include = [acc.replace('.faa', '') for acc in os.listdir(proteome_dir)]
    for acc in proteomes_to_include:
        proteome_path = f'{proteome_dir}/{acc}.faa'
        db_name = acc+'_db'
        out = os.path.join(out_dir, acc, db_name)
        # !makeblastdb -in $proteome_path -dbtype prot -out $out
        
        
def multi_database_query(database_dir, query_filepath, out_dir_path=None):
    """Query each blastp database within the database_dir and make a hits text file in the out_dir"""
        
    if not out_dir_path:
        out_dir_path = './forward_blast_results'
    if not os.path.exists(out_dir_path):
        os.makedirs(out_dir_path)
    for acc in [acc for acc in os.listdir(database_dir) if acc != '.DS_Store']:
        base_filepath = os.path.join(database_dir, f'{acc}/{acc}_db') #filepath of blastp database to query
        out_filepath = os.path.join(out_dir_path, f'{acc}_blastpOut.txt')
        print(out_filepath)
        # !blastp -query $query_filepath -db $base_filepath -num_descriptions 5 -num_alignments 5 -out $out_filepath
        
def recip_blast(rblast_queries_dir, rblast_db_path, outDir):
    """ """
    os.makedirs(outDir)
    query_files = [file for file in os.listdir(rblast_queries_dir) if file.endswith('.faa')]
    for query in query_files:
        outfile_name = query.replace('.faa', '_blastpOut.txt')
        out_path = os.path.join(outDir, f'{outfile_name}')
        query_path  = os.path.join(rblast_queries_dir, query)
        print(query_path,rblast_db_path, out_path, )
        # !blastp -query $query_path -db $rblast_db_path -num_descriptions 5 -num_alignments 5 -out $out_path

# %% [markdown]
# # ENTER THESE PATHS:
# 1. database_dir (str): Enter the desired name of the directory that will house all reciprocal blast results.
# 2. proteome_dir (str): path to the directory containin all of the proteomes used to build the blastp databases and to generate reverse blast queries.
# 3. reference_proteome_path (str): path to the proteome that the original forward query sequence was derived.

# %%
database_dir = './deduped_baumannii_blast_db'
proteome_dir = './Proteomes'
reference_proteome_path = os.path.join(proteome_dir, 'GCF_001077675.1.faa')

# %% [markdown]
# ### Make individual genome blast databases from deduped baumannii genomes + Palmer lab baumannii genomes

# %%
#make_blastp_databases(proteome_dir, out_dir=database_dir, proteomes_to_include=deduped_accessions_w_palmer_strains)

# %%
all_proteomes = [p.replace('.faa', '') for p in os.listdir('./Proteomes')]
len(deduped_accessions_w_palmer_strains)
for a in deduped_accessions_w_palmer_strains:
    p = a.strip() + '.faa'
    if a not in all_proteomes:
        print(a)

# %%
def reciprocal_blastp(database_dir, query_file, out_dirname, proteome_dir, reference_proteome_path, accessions_to_include):
    """
    
    parameters:
    database_dir (str): Path to the parent directory holding all of the individual database folders.
    out_dirname (str): Desired name of the folder holding all results from the different steps of recip. blastp. 
    proteome_dir (str): Path to the directory holding the indivual proteomes (and nothing else). 
    reference_proteome_path (str): Path to the proteome of the orginism from which the original forward query was derived. 
    accessions_to_incluse (list or other iterable): for querying only subset of the proteomes. Otherwise, all proteomes
                    present in './Proteomes' will be queried. 
    
    """
    
    databases  = [db for db in os.listdir(database_dir) if db != '.DS_Store']
    if not accessions_to_include:
        proteomes = [p.replace('.faa', '') for p in os.listdir(proteome_dir)]
    else:
        proteomes = accessions_to_include
    for proteome in proteomes:
        if proteome not in databases:
            raise Exception(f'{proteome} not present in databases')
    for database in databases:
        if database not in proteomes:
            raise Exception(f'{database} not present in proteomes')
            
    os.makedirs(out_dirname)
    forward_results_dir = os.path.join(out_dirname, 'forward_blast_results')
    os.makedirs(forward_results_dir)
    print(forward_results_dir)
    multi_database_query(database_dir, query_file, forward_results_dir)

    rblast_queries_dir = os.path.join(out_dirname, 'forward_best_hits')
    mq.write_best_hit_queries(proteome_dir, forward_results_dir, rblast_queries_dir)
    
    
    ref_db_name = reference_proteome_path.replace('.faa', '_blast_db')
    #os.makedirs('reference_db')
    reference_db_path = os.path.join(out_dirname, 'reference_db/reference_db')
    print(reference_db_path)
    # !makeblastdb -in $reference_proteome_path -dbtype 'prot' -out $reference_db_path
    recip_blast(rblast_queries_dir, reference_db_path, os.path.join(out_dirname,'reciprocal_blast_results'))

# %% [markdown]
# ## Run reciprocal blast

# %% [markdown]
# #### Run # 1 (astA2)

# %%
#### FILL OUT NEXT TWO LINES ################################
query_file_astA2 = './AKQ27614_1_GCA_001077675_1.faa' ##AstA2
out_dirname = './rblast_results_' + query_file_astA2.replace('.faa', '').replace('./','')

reciprocal_blastp(database_dir, query_file=query_file_astA2, out_dirname=out_dirname,
                  proteome_dir=proteome_dir, reference_proteome_path=reference_proteome_path,
                  accessions_to_include = deduped_accessions_w_palmer_strains)

# %% [markdown]
# #### Run # 2 (astC2)

# %%
#### FILL OUT NEXT TWO LINES #################################
query_file_astC2 = './AKQ27615_1_GCA_001077675_1.faa' ##AstC2
out_dirname = './rblast_results_' + query_file_astC2.replace('.faa', '').replace('./','')

reciprocal_blastp(database_dir, query_file=query_file_astC2, out_dirname=out_dirname,
                  proteome_dir=proteome_dir, reference_proteome_path=reference_proteome_path,
                  accessions_to_include = deduped_accessions_w_palmer_strains)
# Out:
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016865465.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024139095.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_019903195.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014159355.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_025246195.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001704675.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_009428985.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_013376855.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022342015.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001399655.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003939525.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001863975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016654295.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014323505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004028375.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004564115.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_904884625.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900477915.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014322245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026273925.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001997285.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_009497505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000305295.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002144765.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900476575.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_019457735.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900496485.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001077555.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003057525.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003994455.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_007999465.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_028548995.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004912245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023896375.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_015537385.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_019703285.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003522845.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003939565.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_007999955.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001708025.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001693095.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026704765.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023499005.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_028583465.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000307895.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000759395.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006367855.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900444775.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023498975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_018863255.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026189845.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023005375.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000021245.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002803025.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000314635.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001077965.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_013787185.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_008802935.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001693195.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001861955.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000302575.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000584415.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000692095.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023371095.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000814345.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_012935125.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000465635.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900406705.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003345235.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_010499945.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006492965.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000584355.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000302235.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024749485.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900496695.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000069245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000786735.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_017349055.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_020255365.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001896005.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000335535.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900444765.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003948385.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022459075.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900476665.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_015265775.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_021726495.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002144805.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024749585.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_013184005.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_015910475.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002017805.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003940105.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027257795.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024173565.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022342205.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_005785165.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003522665.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000770605.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027459865.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900406715.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016654345.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_020810655.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_017168935.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003231185.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027257595.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006493835.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_007999905.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001457535.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002014315.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002927895.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000746605.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000591675.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_902705255.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016125655.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_018883565.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004354145.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003948495.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900118075.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_902705405.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000335635.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_902705505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026273705.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023499155.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_013185155.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023005905.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002148735.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900495895.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023004465.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_009455505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_017349115.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024295235.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027257495.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003039215.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002136995.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_019076685.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001936675.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001721705.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001077675.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000611165.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022937725.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_009736355.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900495045.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022461025.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000369325.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014560035.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024139035.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_008801795.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016506625.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_010500415.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003970215.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_015537675.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000804965.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_021460405.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_015538255.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026062515.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_010499785.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000369165.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000804655.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027257275.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002928075.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000018445.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001693175.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_008709585.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_929606855.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001077575.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_020254495.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000453825.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022937425.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006365895.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016635075.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002573725.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004152715.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002573815.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023371135.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003007025.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001007685.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003231175.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000297935.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_020271605.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022238805.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001891205.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002136655.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003006035.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027257815.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000369265.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026153175.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026704095.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004758865.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000368525.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_019316885.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_008709685.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_009497995.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002573915.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900494975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000505685.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000309235.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000305275.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000304675.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000453925.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900496725.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900118095.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024749425.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900495975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002573735.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900494865.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000453445.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900495355.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026409205.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014560905.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000368125.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_005280675.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016654265.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_021460555.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000805045.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002082685.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016506535.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_025456905.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002142945.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023896495.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003070915.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_021899715.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_005280435.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_021460825.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027558855.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016506845.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027257475.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016654365.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_010500545.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000335595.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003010675.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014559975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003948905.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_017726575.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_904886985.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024749525.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_013416275.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_929607075.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900495605.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000580815.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002947415.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900495315.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001864155.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000516255.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024749465.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_008806535.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002143725.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002837895.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016508455.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_015537525.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003431385.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002183515.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000297515.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002753915.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016864295.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_017098225.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023896795.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_025264005.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_015537765.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006492885.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026190675.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027980265.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002119265.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014169655.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024589115.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002142735.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_009833005.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022467975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000581475.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023004295.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002416475.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024749625.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_012931605.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003336125.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022937745.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001648035.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003948835.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_028439875.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001664765.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006843645.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001895125.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000453165.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002927775.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000413915.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_021020095.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000584595.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_021174225.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023002615.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_019903155.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016506505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001432665.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_009901665.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_008632635.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001693115.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000369245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_025717695.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003007245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001863785.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_008000045.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_015538235.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000309155.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001864535.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_017753625.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022937705.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002573875.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001077655.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006494665.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022467435.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_008124045.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026273385.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024139015.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027257355.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_918809995.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000369305.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022237275.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016506315.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000368545.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000761175.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016508565.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023002245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001864575.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_009737365.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000305215.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003812385.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001864635.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004564095.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900093475.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_028655715.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024505645.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000226275.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900494475.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024271825.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003949015.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_017939285.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003948415.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000493615.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002947845.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_902705485.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002928145.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000498375.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_007113785.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000368205.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027257515.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_013377175.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000297535.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_025457015.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027257415.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_019997865.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_017897205.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002143605.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_005298065.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000580315.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002504145.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024749405.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_929618185.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_005671375.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001516805.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002573825.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_918856805.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_028440165.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900494775.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900496045.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000584095.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026274165.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000805635.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_025941685.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000368245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001693105.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003070935.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006492495.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022342285.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_028402505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_028201495.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023371005.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900496455.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024749645.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022369275.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014893575.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002902885.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014893635.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024749505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006493845.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002727055.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_010499975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_012935005.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_029017525.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004136355.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026675765.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_018863375.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_028745785.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002148745.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900477875.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900444755.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_902705325.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_028440395.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_020982745.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_026620155.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000828795.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_010500385.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900406725.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004794235.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_024589795.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006492855.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002143885.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001862265.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900476825.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900495385.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_018863335.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_011602165.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001441645.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003131025.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_904884545.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023006125.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_904886955.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002922935.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000581895.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_929618915.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001441405.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001874945.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022237585.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_015571935.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001007745.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002082645.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_023370995.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006491975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_008830885.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900406675.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016506985.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003522705.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_904885835.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_009760485.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_904887665.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_022459875.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_012515875.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_018928145.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016919525.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_904886845.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004354165.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002145255.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002184335.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001414575.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000580995.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_900495295.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001077565.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_025258805.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014858045.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002136685.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_000588135.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001028335.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006493855.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_901669965.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001432595.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_012276745.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004194555.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_001573105.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004354125.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_027854725.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_002145155.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_004152685.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_014926505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_902705335.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006494285.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_019891085.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_011683455.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_003431865.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_006492775.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_blast_results/GCF_016903135.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db
#
#
# Building a new DB, current time: 03/27/2023 13:46:17
# New DB name:   /Users/jonwinkelman/Trestle_projects/Palmer_lab/reciprocal_blast_ast_operon/rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db
# New DB title:  ./Proteomes_all/GCF_001077675.1.faa
# Sequence type: Protein
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 3670 sequences in 0.084101 seconds.
#
#
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_017753625.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_017753625.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000368245.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000368245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000369245.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000369245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_003940105.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_003940105.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_003970215.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_003970215.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_021899715.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_021899715.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_900495975.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_900495975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_900494975.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_900494975.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_020271605.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_020271605.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_900495895.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_900495895.1_blastpOut.txt
# ...
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_027558855.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_027558855.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_028745785.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_028745785.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_006494285.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_006494285.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_027257795.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_027257795.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_009497995.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_009497995.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_008709685.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_008709685.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_002727055.2.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_002727055.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_006365895.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_006365895.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_024749625.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_024749625.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_027257415.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_027257415.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_010500545.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_010500545.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_024295235.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_024295235.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_015538235.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_015538235.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_014323505.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_014323505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_017098225.2.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_017098225.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_002837895.2.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_002837895.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000814345.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000814345.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_001516805.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_001516805.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000309155.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000309155.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_001077575.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_001077575.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_024749585.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_024749585.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_002145255.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_002145255.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000516255.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000516255.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_007999955.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_007999955.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_016654365.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_016654365.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_902705485.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_902705485.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_024749465.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_024749465.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_008802935.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_008802935.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000309235.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000309235.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_003522665.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_003522665.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_014893635.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_014893635.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_001414575.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_001414575.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_006492775.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_006492775.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_900495385.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_900495385.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000069245.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000069245.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_023371135.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_023371135.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_002573725.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_002573725.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_904887665.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_904887665.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_028548995.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_028548995.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000759395.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000759395.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_025246195.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_025246195.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_017349115.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_017349115.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000305275.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000305275.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_002014315.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_002014315.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000805045.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000805045.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_003070915.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_003070915.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_022467435.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_022467435.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_904886955.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_904886955.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_011602165.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_011602165.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000021245.2.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000021245.2_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_001693095.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_001693095.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_002573815.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_002573815.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_006493845.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_006493845.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_001693175.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_001693175.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_022937705.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_022937705.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_000302235.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_000302235.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_002136655.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_002136655.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_006492885.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_006492885.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_006492965.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_006492965.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_020255365.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_020255365.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_003812385.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_003812385.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_028402505.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_028402505.1_blastpOut.txt
# ./rblast_results_AKQ27615_1_GCA_001077675_1/forward_best_hits/GCF_002148745.1.faa ./rblast_results_AKQ27615_1_GCA_001077675_1/reference_db/reference_db ./rblast_results_AKQ27615_1_GCA_001077675_1/reciprocal_blast_results/GCF_002148745.1_blastpOut.txt

# %% [markdown]
# ### Processing rblast data

# %%
def get_blastbesthit_dict(path_to_blast_results, accession_length=13):
    """Return a dict {accession:protein_id} with the accession of genome and the best hit in the source genome"""
    
    files =os.listdir(path_to_blast_results)
    paths = [os.path.join(path_to_blast_results,file) for file in files]
    best_hits_dict = {}
    for file, path in zip(files, paths):
        accession = file[:accession_length]
        with open(path, 'r') as f:
            for i,line in enumerate(f):
                if line.startswith('>'):
                    prot_id = line.split(' ')[0][1:]
                    best_hits_dict[accession]=prot_id
                    break
    return best_hits_dict

def get_full_best_hits_dict(recip_blast_dir, accession_length=15):
    for_dir = os.path.join(recip_blast_dir, 'forward_blast_results')
    rev_dir = os.path.join(recip_blast_dir, 'reciprocal_blast_results')
    forward_bbhits = get_blastbesthit_dict(for_dir, accession_length=accession_length)
    rev_bbhits = get_blastbesthit_dict(rev_dir, accession_length=accession_length)
    full_df = pd.DataFrame.from_dict(rev_bbhits, orient='index').merge(pd.DataFrame.from_dict(forward_bbhits, orient='index'), left_index=True, right_index=True)
    full_df.columns = ['r_bbhit', 'f_bbhit']
    return full_df

astA_df = get_full_best_hits_dict('./rblast_results_AKQ27614_1', accession_length=15)
astC_df = get_full_best_hits_dict('./rblast_results_AKQ27615_1_GCA_001077675_1', accession_length=15)

# %%
astC_df['r_bbhit'].value_counts()
# Out:
# WP_005135515.1    377
# WP_009518196.1     86
# WP_000129946.1      4
# Name: r_bbhit, dtype: int64

# %%
astA_df['r_bbhit'].value_counts()
# Out:
# WP_000972684.1    376
# WP_000973732.1     89
# WP_000205079.1      2
# Name: r_bbhit, dtype: int64

# %%
astC_df['r_bbhit'].value_counts()['WP_005135515.1'] / astC_df.shape[0]
# Out:
# 0.8072805139186295

# %%
astA_df['r_bbhit'].value_counts()['WP_000972684.1'] / astA_df.shape[0]
# Out:
# 0.8051391862955032

# %% [markdown]
# ### Save to file

# %%
astA_df.to_csv('./rblast_results_AKQ27614_1/results_recip_blast_astA2.csv')
astC_df.to_csv('./rblast_results_AKQ27615_1_GCA_001077675_1/results_recip_blast_astC2.csv')
